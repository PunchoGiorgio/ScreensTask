# %% [markdown]
# <a href="https://colab.research.google.com/github/PunchoGiorgio/ScreensTask/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22homework_9_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Крок 1
#
#
#
# > Перевірте чи встановлений у вас менеджер пакетів pip. Виконайте наступний код в терміналі:
#
#
#
# ```
# pip
# ```
#
#
#
# > Результат має бути:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Крок 2
#
#
# >  Спробуйте встановити бібліотеку requests
#
#
# *   [requests](https://requests.readthedocs.io/en/latest/) (почитати більше про неї)
# *   [http запити 1](https://selectel.ru/blog/http-request/)
# *   [http запити 2](ting.ua/ru/http_and_https_protocols.php)

# %% [markdown]
# # Крок 3
#
#
# >  Перевірте чи установка пройшла вдало. Виконайте наступну команду в терміналі та знайдіть requests.
#
#
#
# ```
# pip list
# ```
#
# > Результат має бути:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Крок 4
#
#
# > Створення віртуального середовища. Створіть новий проект у вашому редакторі коду, бажано vscode. В терміналі редактору коду виконайте наступну команду:
#
#
#
# ```
# python -m venv venv
# ```
#
#
# > У дерикторії проекту має зявитися нова тека.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Крок 5
#
#
#
# > Встановіть на рівні проекту бібліотеку яка б могла вас зацікавити, або будь-яку зі списка [awesome python](https://github.com/vinta/awesome-python)

# %% [markdown]
# # Крок 6
#
#
#
# > Перевірте чи установка пройшла вдало. ВИКОНАЙТЕ НАСТУПНУ КОМАНДУ В ТЕРМІНАЛІ ТА ЗРОБІТЬ СКРІНШОТ (ДОДАЙТЕ ЙОГО У ВАШ БЛОКНТО ДЛЯ ЗДАЧІ ДЗ)
#
#
#
#
# ```
# pip list
# ```

# %% [markdown]
# # Крок 7
#
#
# > Свторіть файл main.py та вставте наступний код в середину файлу. Запустіть ваш файл з кодом.
#
#
#
# ```
# import requests
#
# r = requests.get('https://www.helloworld.org/')
# print(r.text)
# ```
#
#
# ЗРОБІТЬ СКРІНШОТ СВОГО ТЕРМІНАЛУ ТА ДОДАЙТЕ В БЛОКНОТ ДЛЯ ЗДАЧІ ЦЬОГО ДЗ.
